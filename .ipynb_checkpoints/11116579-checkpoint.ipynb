# %% [markdown]
# # NHYIRA BENTSIL, 11116579, MTEN

# %% [markdown]
# ### Question 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Question 3

# %%
dataset = pd.read_csv('red_wine.csv') 
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4      5.0
# 1         9.8      5.0
# 2         9.8      5.0
# 3         9.8      6.0
# 4         9.4      5.0
# ...       ...      ...
# 1594     10.5      5.0
# 1595     11.2      6.0
# 1596     11.0      6.0
# 1597     10.2      5.0
# 1598     11.0      6.0
#
# [1599 rows x 12 columns]

# %% [markdown]
# ### Question 4

# %%
firstTenRows = dataset.head(10)
firstTenRows
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4      5.0
# 1      9.8      5.0
# 2      9.8      5.0
# 3      9.8      6.0
# 4      9.4      5.0
# 5      9.4      5.0
# 6      9.4      5.0
# 7     10.0      7.0
# 8      9.5      7.0
# 9     10.5      5.0

# %% [markdown]
# ### Question 5

# %%
lastTwentyRows = dataset.tail(20)
lastTwentyRows
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1579                 24.0                  32.0  0.99402  3.54       0.60
# 1580                  9.0                  26.0  0.99470  3.36       0.60
# 1581                 24.0                  32.0  0.99402  3.54       0.60
# 1582                 13.0                  27.0  0.99362  3.57       0.50
# 1583                 32.0                  98.0  0.99578  3.33       0.62
# 1584                 24.0                  34.0  0.99484  3.29       0.80
# 1585                 22.0                  48.0  0.99494  3.30       0.84
# 1586                 34.0                  60.0  0.99492  3.34       0.85
# 1587                 18.0                  28.0  0.99483  3.55       0.66
# 1588                 34.0                 102.0  0.99414  3.27       0.78
# 1589                 29.0                  79.0  0.99770  3.29       0.54
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1579     11.3      5.0
# 1580     11.9      6.0
# 1581     11.3      5.0
# 1582     11.9      5.0
# 1583      9.8      5.0
# 1584     11.6      7.0
# 1585     11.5      6.0
# 1586     11.4      6.0
# 1587     10.9      6.0
# 1588     12.8      6.0
# 1589      9.2      5.0
# 1590     11.6      6.0
# 1591     11.6      6.0
# 1592     11.0      6.0
# 1593      9.5      6.0
# 1594     10.5      5.0
# 1595     11.2      6.0
# 1596     11.0      6.0
# 1597     10.2      5.0
# 1598     11.0      6.0

# %% [markdown]
# ### Question 6

# %%
dataset = dataset.dropna()

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1590 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1590 non-null   float64
#  1   volatile acidity      1590 non-null   float64
#  2   citric acid           1590 non-null   float64
#  3   residual sugar        1590 non-null   float64
#  4   chlorides             1590 non-null   float64
#  5   free sulfur dioxide   1590 non-null   float64
#  6   total sulfur dioxide  1590 non-null   float64
#  7   density               1590 non-null   float64
#  8   pH                    1590 non-null   float64
#  9   sulphates             1590 non-null   float64
#  10  alcohol               1590 non-null   float64
#  11  quality               1590 non-null   float64
# dtypes: float64(12)
# memory usage: 161.5 KB

# %% [markdown]
# ### Question 7

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1590.000000       1590.000000  1590.000000     1590.000000
# mean        8.315849          0.527978     0.270786        2.539277
# std         1.742820          0.179108     0.194780        1.412957
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1590.000000          1590.000000           1590.000000  1590.000000
# mean      0.087425            15.847170             46.357233     0.996742
# std       0.047135            10.434785             32.812400     0.001889
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996745
# 75%       0.090000            21.000000             62.000000     0.997827
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1590.000000  1590.000000  1590.000000  1590.000000
# mean      3.311308     0.658220    10.428208     5.637736
# std       0.154489     0.169622     1.066296     0.808753
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# ### Question 8

# %%
x = dataset['fixed acidity']
y = dataset['volatile acidity']

plt.scatter(x, y)
plt.xlabel('fixed acidity')
plt.ylabel('volatile acidity')
plt.title('Scatter Plot of fixed acidity vs volatile acidity')
plt.show()

# %%
x = dataset['fixed acidity']
y = dataset['citric acid']

plt.scatter(x, y)
plt.xlabel('fixed acidity')
plt.ylabel('citric acid')
plt.title('Scatter Plot of Fixed acidity vs citric acid')
plt.show()

# %%
x = dataset['fixed acidity']
y = dataset['pH']

plt.scatter(x, y)
plt.xlabel('Fixed acidity')
plt.ylabel('pH')
plt.title('Scatter Plot of Fixed acidity vs pH')
plt.show()

# %%
x = dataset['residual sugar']
y = dataset['quality']

plt.scatter(x, y)
plt.xlabel('residual sugar')
plt.ylabel('quality')
plt.title('Scatter Plot of residual sugar vs. quality')
plt.show()

# %%
x = dataset['density']
y = dataset['alcohol']

plt.scatter(x, y)
plt.xlabel('density')
plt.ylabel('alcohol')
plt.title('Scatter Plot of density  vs alcohol')
plt.show()

# %%
x = dataset['total sulfur dioxide']
y = dataset['free sulfur dioxide']

plt.scatter(x, y)
plt.xlabel('total sulfur dioxide')
plt.ylabel('free sulfur dioxide')
plt.title('Scatter Plot of total sulfur dioxide  vs free sulfur dioxide')
plt.show()

# %%
x = dataset['pH']
y = dataset['quality']

plt.scatter(x, y)
plt.xlabel('pH ')
plt.ylabel('quality')
plt.title('Scatter Plot of pH   vs. quality')
plt.show()

# %%
x = dataset['sulphates']
y = dataset['quality']

plt.scatter(x, y)
plt.xlabel('sulphates')
plt.ylabel('quality')
plt.title('Scatter Plot of sulphates vs. quality')
plt.show()

# %%
x = dataset['alcohol']
y = dataset['quality']

plt.scatter(x, y)
plt.xlabel('alcohol')
plt.ylabel('quality')
plt.title('Scatter Plot of alcohol vs. quality')
plt.show()

# %% [markdown]
# ## Question 9
# ### Conclusions from graphs

# %% [markdown]
# #### Fixed acidity against volatile acidity
# <strong> This graph showed a negative correlative between the fixed acidity and the volatile acidity. The scatter graph of the fixed acidity against the volatile acidity shows that as the fixed acidity increases the volatile acidity decreases.</strong>
#
# ---
#
# #### Fixed acidity against citric acid
# <strong> In regards to the scatter graph of the fixed acidity against the citric acid, the graph showed a positive correlation between the fixed acidity concentration and the citric acid concentration. As the fixed acidity increased, the the citric acid concentration also increased.  </strong>
#
# ---
#
#
# #### Fixed acidity against pH
# <strong> The scatter graph of the fixed acidity against the pH shows that there is a positive correlation between the fixed acidity and the pH of the red wine. As the fixed acidity concentration increased, the pH decreased making the wine more acidic. This also implies a negative correlation between the volatile acidity and the pH. It is expected that, as the volatile acidity concentration increases, the pH would increase.</strong>
#
# ---
#
# #### Residual sugar against quality
# <strong> The scatter graph of the residual sugar against the quality shows that there is little or no correlation between the residual sugar concentration and the quality of the red wine. The wines with the best quality had a residual sugar concentration ranging between 1 and 7g/L, whiles the wines with the worst quality had a concentration between 1 and 6 g/L. The graph showed an increase in quality as the residual sugar concentration increased up to a quality of 6, and then a decrease from a quality of 6 up to 8, as the concentration decreased.</strong>
#
# ---
#
#
# #### Density vs alcohol concentration
# <strong> The scatter graph of density against alcohol concentrations shows that there is a negative correlation between density and alcohol concentrations  of the red wine. As the density of the wine increased, the alcohol concentration decreased </strong>
#
# ---
#
# #### total sulfur dioxide against free sulfur dioxide
# <strong> The scatter graph of the total sulfur dioxide concentration against the free sulfur dioxide shows that there is a positive correlation between the total sulfur dioxide concentration and the free sulfur dioxide concentration of the red wine. As the total sulfur dioxide concentration increased so did the free sulfur dioxide concentration also increase. </strong>
#
# ---
#
# #### pH against quality
# <strong> The scatter graph pH against the quality shows that there is no correlation between the pH and the quality of the red wine. The wines with the best quality, had a pH  ranging between 2.8 and 3.8, whiles the the wines with the worst quality had a pH between 3.1 and 3.7. The graph showed an increase in quality as the  pH increased up to a quality of 6, and then a decrease from a quality of 6 up to 8, as the pH decreased. </strong>
#
# ---
#
# #### sulphates against quality
# <strong> The scatter graph of the sulphates concentration against the quality shows that there is no correlation between the sulphates concentration and the quality of the red wine. The wines with the best quality, had a sulphates concentration ranging between 0.60 and 1.25 mg/L, whiles the the wines with the worst quality had a pH between 0.25 and 1 mg/L. The graph showed an increase in quality as the sulphates concentration increased up to a quality of 6, and then a decrease from a quality of 6 up to 8, as the sulphates concentration decreased. </strong>
#
# ---
#
#
# #### Alcohol against quality
# <strong> The scatter graph of the alcohol concentration against the quality shows that there is a positive correlation between the alcohol concentration and the quality of the red wine. As the alchol concentration of the wine increased, the quality increased, implying that alcohol concentration could be a strong determinant in the quality of red wine. </strong>
#
# ---
